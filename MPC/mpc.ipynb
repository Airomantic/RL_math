# %%
import numpy as np
from scipy.stats import truncnorm
import gym
import itertools
import torch
import torch.nn as nn
import torch.nn.functional as F
import collections
import matplotlib.pyplot as plt


class CEM:
    def __init__(self, n_sequence, elite_ratio, fake_env, upper_bound,
                 lower_bound):
        self.n_sequence = n_sequence
        self.elite_ratio = elite_ratio
        self.upper_bound = upper_bound
        self.lower_bound = lower_bound
        self.fake_env = fake_env

    def optimize(self, state, init_mean, init_var):
        mean, var = init_mean, init_var
        X = truncnorm(-2, 2, loc=np.zeros_like(mean), scale=np.ones_like(var))
        state = np.tile(state, (self.n_sequence, 1))

        for _ in range(5):
            lb_dist, ub_dist = mean - self.lower_bound, self.upper_bound - mean
            constrained_var = np.minimum(
                np.minimum(np.square(lb_dist / 2), np.square(ub_dist / 2)),
                var)
            # 生成动作序列
            action_sequences = [X.rvs() for _ in range(self.n_sequence)
                                ] * np.sqrt(constrained_var) + mean
            # 计算每条动作序列的累积奖励
            returns = self.fake_env.propagate(state, action_sequences)[:, 0]
            # 选取累积奖励最高的若干条动作序列
            elites = action_sequences[np.argsort(
                returns)][-int(self.elite_ratio * self.n_sequence):]
            new_mean = np.mean(elites, axis=0)
            new_var = np.var(elites, axis=0)
            # 更新动作序列分布
            mean = 0.1 * mean + 0.9 * new_mean
            var = 0.1 * var + 0.9 * new_var

        return mean

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device(
    "cpu")


class Swish(nn.Module):
    ''' Swish激活函数 '''
    def __init__(self):
        super(Swish, self).__init__()

    def forward(self, x):
        return x * torch.sigmoid(x)


def init_weights(m):
    ''' 初始化模型权重 '''
    def truncated_normal_init(t, mean=0.0, std=0.01):
        torch.nn.init.normal_(t, mean=mean, std=std)
        while True:
            cond = (t < mean - 2 * std) | (t > mean + 2 * std)
            if not torch.sum(cond):
                break
            t = torch.where(
                cond,
                torch.nn.init.normal_(torch.ones(t.shape, device=device),
                                      mean=mean,
                                      std=std), t)
        return t

    if type(m) == nn.Linear or isinstance(m, FCLayer):
        truncated_normal_init(m.weight, std=1 / (2 * np.sqrt(m._input_dim)))
        m.bias.data.fill_(0.0)


class FCLayer(nn.Module):
    ''' 集成之后的全连接层 '''
    def __init__(self, input_dim, output_dim, ensemble_size, activation):
        super(FCLayer, self).__init__()
        self._input_dim, self._output_dim = input_dim, output_dim
        self.weight = nn.Parameter(
            torch.Tensor(ensemble_size, input_dim, output_dim).to(device))
        self._activation = activation
        self.bias = nn.Parameter(
            torch.Tensor(ensemble_size, output_dim).to(device))

    def forward(self, x):
        return self._activation(
            torch.add(torch.bmm(x, self.weight), self.bias[:, None, :]))

# %%
class EnsembleModel(nn.Module):
    ''' 环境模型集成 '''
    def __init__(self,
                 state_dim,
                 action_dim,
                 ensemble_size=5,
                 learning_rate=1e-3):
        super(EnsembleModel, self).__init__()
        # 输出包括均值和方差,因此是状态与奖励维度之和的两倍
        self._output_dim = (state_dim + 1) * 2
        self._max_logvar = nn.Parameter((torch.ones(
            (1, self._output_dim // 2)).float() / 2).to(device),
                                        requires_grad=False)
        self._min_logvar = nn.Parameter((-torch.ones(
            (1, self._output_dim // 2)).float() * 10).to(device),
                                        requires_grad=False)

        self.layer1 = FCLayer(state_dim + action_dim, 200, ensemble_size,
                              Swish())
        self.layer2 = FCLayer(200, 200, ensemble_size, Swish())
        self.layer3 = FCLayer(200, 200, ensemble_size, Swish())
        self.layer4 = FCLayer(200, 200, ensemble_size, Swish())
        self.layer5 = FCLayer(200, self._output_dim, ensemble_size,
                              nn.Identity())
        self.apply(init_weights)  # 初始化环境模型中的参数
        self.optimizer = torch.optim.Adam(self.parameters(), lr=learning_rate)

    def forward(self, x, return_log_var=False):
        ret = self.layer5(self.layer4(self.layer3(self.layer2(
            self.layer1(x)))))
        mean = ret[:, :, :self._output_dim // 2]
        # 在PETS算法中,将方差控制在最小值和最大值之间
        logvar = self._max_logvar - F.softplus(
            self._max_logvar - ret[:, :, self._output_dim // 2:])
        logvar = self._min_logvar + F.softplus(logvar - self._min_logvar)
        return mean, logvar if return_log_var else torch.exp(logvar)

    def loss(self, mean, logvar, labels, use_var_loss=True):
        inverse_var = torch.exp(-logvar)
        if use_var_loss:
            mse_loss = torch.mean(torch.mean(torch.pow(mean - labels, 2) *
                                             inverse_var,
                                             dim=-1),
                                  dim=-1)
            var_loss = torch.mean(torch.mean(logvar, dim=-1), dim=-1)
            total_loss = torch.sum(mse_loss) + torch.sum(var_loss)
        else:
            mse_loss = torch.mean(torch.pow(mean - labels, 2), dim=(1, 2))
            total_loss = torch.sum(mse_loss)
        return total_loss, mse_loss

    def train(self, loss):
        self.optimizer.zero_grad()
        loss += 0.01 * torch.sum(self._max_logvar) - 0.01 * torch.sum(
            self._min_logvar)
        loss.backward()
        self.optimizer.step()

# %%
class EnsembleDynamicsModel:
    ''' 环境模型集成,加入精细化的训练 '''
    def __init__(self, state_dim, action_dim, num_network=5):
        self._num_network = num_network
        self._state_dim, self._action_dim = state_dim, action_dim
        self.model = EnsembleModel(state_dim,
                                   action_dim,
                                   ensemble_size=num_network)
        self._epoch_since_last_update = 0

    def train(self,
              inputs,
              labels,
              batch_size=64,
              holdout_ratio=0.1,
              max_iter=20):
        # 设置训练集与验证集
        permutation = np.random.permutation(inputs.shape[0])
        inputs, labels = inputs[permutation], labels[permutation]
        num_holdout = int(inputs.shape[0] * holdout_ratio)
        train_inputs, train_labels = inputs[num_holdout:], labels[num_holdout:]
        holdout_inputs, holdout_labels = inputs[:
                                                num_holdout], labels[:
                                                                     num_holdout]
        holdout_inputs = torch.from_numpy(holdout_inputs).float().to(device)
        holdout_labels = torch.from_numpy(holdout_labels).float().to(device)
        holdout_inputs = holdout_inputs[None, :, :].repeat(
            [self._num_network, 1, 1])
        holdout_labels = holdout_labels[None, :, :].repeat(
            [self._num_network, 1, 1])

        # 保留最好的结果
        self._snapshots = {i: (None, 1e10) for i in range(self._num_network)}

        for epoch in itertools.count():
            # 定义每一个网络的训练数据
            train_index = np.vstack([
                np.random.permutation(train_inputs.shape[0])
                for _ in range(self._num_network)
            ])
            # 所有真实数据都用来训练
            for batch_start_pos in range(0, train_inputs.shape[0], batch_size):
                batch_index = train_index[:, batch_start_pos:batch_start_pos +
                                          batch_size]
                train_input = torch.from_numpy(
                    train_inputs[batch_index]).float().to(device)
                train_label = torch.from_numpy(
                    train_labels[batch_index]).float().to(device)

                mean, logvar = self.model(train_input, return_log_var=True)
                loss, _ = self.model.loss(mean, logvar, train_label)
                self.model.train(loss)

            with torch.no_grad():
                mean, logvar = self.model(holdout_inputs, return_log_var=True)
                _, holdout_losses = self.model.loss(mean,
                                                    logvar,
                                                    holdout_labels,
                                                    use_var_loss=False)
                holdout_losses = holdout_losses.cpu()
                break_condition = self._save_best(epoch, holdout_losses)
                if break_condition or epoch > max_iter:  # 结束训练
                    break

    def _save_best(self, epoch, losses, threshold=0.1):
        updated = False
        for i in range(len(losses)):
            current = losses[i]
            _, best = self._snapshots[i]
            improvement = (best - current) / best
            if improvement > threshold:
                self._snapshots[i] = (epoch, current)
                updated = True
        self._epoch_since_last_update = 0 if updated else self._epoch_since_last_update + 1
        return self._epoch_since_last_update > 5

    def predict(self, inputs, batch_size=64):
        mean, var = [], []
        for i in range(0, inputs.shape[0], batch_size):
            input = torch.from_numpy(
                inputs[i:min(i +
                             batch_size, inputs.shape[0])]).float().to(device)
            cur_mean, cur_var = self.model(input[None, :, :].repeat(
                [self._num_network, 1, 1]),
                                           return_log_var=False)
            mean.append(cur_mean.detach().cpu().numpy())
            var.append(cur_var.detach().cpu().numpy())
        return np.hstack(mean), np.hstack(var)

# %%
class FakeEnv:
    def __init__(self, model):
        self.model = model

    def step(self, obs, act):
        inputs = np.concatenate((obs, act), axis=-1)
        ensemble_model_means, ensemble_model_vars = self.model.predict(inputs)
        ensemble_model_means[:, :, 1:] += obs.numpy()
        ensemble_model_stds = np.sqrt(ensemble_model_vars)
        ensemble_samples = ensemble_model_means + np.random.normal(
            size=ensemble_model_means.shape) * ensemble_model_stds

        num_models, batch_size, _ = ensemble_model_means.shape
        models_to_use = np.random.choice(
            [i for i in range(self.model._num_network)], size=batch_size)
        batch_inds = np.arange(0, batch_size)
        samples = ensemble_samples[models_to_use, batch_inds]
        rewards, next_obs = samples[:, :1], samples[:, 1:]
        return rewards, next_obs

    def propagate(self, obs, actions):
        with torch.no_grad():
            obs = np.copy(obs)
            total_reward = np.expand_dims(np.zeros(obs.shape[0]), axis=-1)
            obs, actions = torch.as_tensor(obs), torch.as_tensor(actions)
            for i in range(actions.shape[1]):
                action = torch.unsqueeze(actions[:, i], 1)
                rewards, next_obs = self.step(obs, action)
                total_reward += rewards
                obs = torch.as_tensor(next_obs)
            return total_reward

# %%
class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = collections.deque(maxlen=capacity)

    def add(self, state, action, reward, next_state, done):
        self.buffer.append((state, action, reward, next_state, done))

    def size(self):
        return len(self.buffer)

    def return_all_samples(self):
        all_transitions = list(self.buffer)
        state, action, reward, next_state, done = zip(*all_transitions)
        return np.array(state), action, reward, np.array(next_state), done

# %%
class PETS:
    ''' PETS算法 '''
    def __init__(self, env, replay_buffer, n_sequence, elite_ratio,
                 plan_horizon, num_episodes):
        self._env = env
        self._env_pool = ReplayBuffer(buffer_size)

        obs_dim = env.observation_space.shape[0]
        self._action_dim = env.action_space.shape[0]
        self._model = EnsembleDynamicsModel(obs_dim, self._action_dim)
        self._fake_env = FakeEnv(self._model)
        self.upper_bound = env.action_space.high[0]
        self.lower_bound = env.action_space.low[0]

        self._cem = CEM(n_sequence, elite_ratio, self._fake_env,
                        self.upper_bound, self.lower_bound)
        self.plan_horizon = plan_horizon
        self.num_episodes = num_episodes

    def train_model(self):
        env_samples = self._env_pool.return_all_samples()
        obs = env_samples[0]
        actions = np.array(env_samples[1])
        rewards = np.array(env_samples[2]).reshape(-1, 1)
        next_obs = env_samples[3]
        inputs = np.concatenate((obs, actions), axis=-1)
        labels = np.concatenate((rewards, next_obs - obs), axis=-1)
        self._model.train(inputs, labels)

    def mpc(self):
        mean = np.tile((self.upper_bound + self.lower_bound) / 2.0,
                       self.plan_horizon)
        var = np.tile(
            np.square(self.upper_bound - self.lower_bound) / 16,
            self.plan_horizon)
        obs, done, episode_return = self._env.reset(), False, 0
        while not done:
            actions = self._cem.optimize(obs, mean, var)
            action = actions[:self._action_dim]  # 选取第一个动作
            next_obs, reward, done, _ = self._env.step(action)
            self._env_pool.add(obs, action, reward, next_obs, done)
            obs = next_obs
            episode_return += reward
            mean = np.concatenate([
                np.copy(actions)[self._action_dim:],
                np.zeros(self._action_dim)
            ])
        return episode_return

    def explore(self):
        obs, done, episode_return = self._env.reset(), False, 0
        while not done:
            action = self._env.action_space.sample()
            # print("self._env.step(action) = ", self._env.step(action))
            next_obs, reward, done, _, info = self._env.step(action)
            self._env_pool.add(obs, action, reward, next_obs, done)
            obs = next_obs
            episode_return += reward
        return episode_return

    def train(self):
        return_list = []
        explore_return = self.explore()  # 先进行随机策略的探索来收集一条序列的数据
        print('episode: 1, return: %d' % explore_return)
        return_list.append(explore_return)

        for i_episode in range(self.num_episodes - 1):
            self.train_model()
            episode_return = self.mpc()
            return_list.append(episode_return)
            print('episode: %d, return: %d' % (i_episode + 2, episode_return))
        return return_list

# %%
buffer_size = 100000
n_sequence = 50
elite_ratio = 0.2
plan_horizon = 25
num_episodes = 10
env_name = 'Pendulum-v1'
env = gym.make(env_name)

replay_buffer = ReplayBuffer(buffer_size)
pets = PETS(env, replay_buffer, n_sequence, elite_ratio, plan_horizon,
            num_episodes)
return_list = pets.train()

episodes_list = list(range(len(return_list)))
plt.plot(episodes_list, return_list)
plt.xlabel('Episodes')
plt.ylabel('Returns')
plt.title('PETS on {}'.format(env_name))
plt.show()

# episode: 1, return: -1062
# episode: 2, return: -1257
# episode: 3, return: -1792
# episode: 4, return: -1225
# episode: 5, return: -248
# episode: 6, return: -124
# episode: 7, return: -249
# episode: 8, return: -269
# episode: 9, return: -245
# episode: 10, return: -119
# Out:
# /home/jiang_qwin/.local/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# self._env.step(action) =  (array([-0.49499655,  0.86889493, -0.37186977], dtype=float32), -4.525786923137594, False, False, {})
# self._env.step(action) =  (array([-0.5261872,  0.8503688,  0.5403049], dtype=float32), -4.408403032307562, False, False, {})
# self._env.step(action) =  (array([-0.6248776 ,  0.78072274,  1.5323895 ], dtype=float32), -4.783556319646057, False, False, {})
# self._env.step(action) =  (array([-0.7863543,  0.6177758,  2.4524813], dtype=float32), -5.999550774696448, False, False, {})
# self._env.step(action) =  (array([-0.93149817,  0.363746  ,  3.1819236 ], dtype=float32), -7.537666357771289, False, False, {})
# self._env.step(action) =  (array([-0.99995506,  0.0094796 ,  3.6900892 ], dtype=float32), -9.960078506908962, False, False, {})
# self._env.step(action) =  (array([-0.9409011 , -0.33868146,  3.423228  ], dtype=float32), -10.156973282018717, False, False, {})
# self._env.step(action) =  (array([-0.8105643 , -0.58564967,  2.5574439 ], dtype=float32), -7.918083481016421, False, False, {})
# self._env.step(action) =  (array([-0.69884354, -0.7152746 ,  1.438813  ], dtype=float32), -6.234844529094518, False, False, {})
# self._env.step(action) =  (array([-0.65764904, -0.75332445,  0.27104872], dtype=float32), -5.371783110794347, False, False, {})
# self._env.step(action) =  (array([-0.69913745, -0.7149873 , -0.8146292 ], dtype=float32), -5.319682672636433, False, False, {})
# self._env.step(action) =  (array([-0.80358404, -0.5951913 , -1.8889971 ], dtype=float32), -5.973956186412524, False, False, {})
# self._env.step(action) =  (array([-0.93315107, -0.35948443, -2.9656699 ], dtype=float32), -7.485497994602779, False, False, {})
# self._env.step(action) =  (array([-0.9995496 , -0.03000972, -3.3532195 ], dtype=float32), -9.824883756191578, False, False, {})
# self._env.step(action) =  (array([-0.9588055,  0.2840633, -3.1800208], dtype=float32), -10.087731879724341, False, False, {})
# self._env.step(action) =  (array([-0.8420493,  0.5394006, -2.5712686], dtype=float32), -8.231609372524044, False, False, {})
# self._env.step(action) =  (array([-0.7389088,  0.6738054, -1.396851 ], dtype=float32), -6.510245770901716, False, False, {})
# self._env.step(action) =  (array([-0.7003741 ,  0.71377593, -0.3523474 ], dtype=float32), -5.648211044138617, False, False, {})
# self._env.step(action) =  (array([-0.71635747,  0.69773346,  0.39006865], dtype=float32), -5.52413434080592, False, False, {})
# self._env.step(action) =  (array([-0.7869195 ,  0.61705565,  1.4377567 ], dtype=float32), -5.834885250143129, False, False, {})
# self._env.step(action) =  (array([-0.90909415,  0.41659072,  2.5786607 ], dtype=float32), -7.124439360630743, False, False, {})
# self._env.step(action) =  (array([-0.9929167 ,  0.11881235,  3.267129  ], dtype=float32), -9.042471777635994, False, False, {})
# self._env.step(action) =  (array([-0.9776261 , -0.21035038,  3.151041  ], dtype=float32), -10.738043846571438, False, False, {})
# self._env.step(action) =  (array([-0.89679635, -0.4424436 ,  2.2121804 ], dtype=float32), -8.545936233218681, False, False, {})
# self._env.step(action) =  (array([-0.8230923 , -0.56790763,  1.2802949 ], dtype=float32), -7.035117187482235, False, False, {})
# self._env.step(action) =  (array([-0.79195577, -0.6105785 ,  0.1688619 ], dtype=float32), -6.298219231433668, False, False, {})
# self._env.step(action) =  (array([-0.8361202 , -0.54854625, -0.9682947 ], dtype=float32), -6.343765185700175, False, False, {})
# self._env.step(action) =  (array([-0.91452235, -0.40453532, -1.9313859 ], dtype=float32), -7.0939859394272275, False, False, {})
# self._env.step(action) =  (array([-0.9858867, -0.167414 , -2.5189319], dtype=float32), -8.707315163360963, False, False, {})
# self._env.step(action) =  (array([-0.9957319 ,  0.09229318, -2.7129977 ], dtype=float32), -10.226145430289176, False, False, {})
# self._env.step(action) =  (array([-0.9283733 ,  0.37164912, -2.9424517 ], dtype=float32), -9.25775336159353, False, False, {})
# self._env.step(action) =  (array([-0.78527874,  0.61914235, -2.7822337 ], dtype=float32), -7.703172800271614, False, False, {})
# self._env.step(action) =  (array([-0.62107176,  0.7837537 , -2.1374948 ], dtype=float32), -6.1497347832103975, False, False, {})
# self._env.step(action) =  (array([-0.49607018,  0.86828244, -1.322143  ], dtype=float32), -4.939516805117351, False, False, {})
# self._env.step(action) =  (array([-0.4434231 ,  0.8963124 , -0.27347645], dtype=float32), -4.262046200097156, False, False, {})
# self._env.step(action) =  (array([-0.51718575,  0.85587317,  1.3056712 ], dtype=float32), -4.215992660559376, False, False, {})
# self._env.step(action) =  (array([-0.70644873,  0.70776427,  2.6079993 ], dtype=float32), -5.4402372426104035, False, False, {})
# self._env.step(action) =  (array([-0.885611 ,  0.4644278,  3.125358 ], dtype=float32), -7.129981679461856, False, False, {})
# self._env.step(action) =  (array([-0.98864716,  0.15025565,  3.4330847 ], dtype=float32), -8.977903670514307, False, False, {})
# self._env.step(action) =  (array([-0.98222435, -0.18771073,  3.2621315 ], dtype=float32), -10.958217330163786, False, False, {})
# self._env.step(action) =  (array([-0.8969969, -0.4420368,  2.5089965], dtype=float32), -8.716772660169989, False, False, {})
# self._env.step(action) =  (array([-0.8003005, -0.5995992,  1.6431758], dtype=float32), -7.084430472845133, False, False, {})
# self._env.step(action) =  (array([-0.7425025 , -0.66984326,  0.643839  ], dtype=float32), -6.0909866306566105, False, False, {})
# self._env.step(action) =  (array([-0.7509617 , -0.66034573, -0.3477547 ], dtype=float32), -5.775105696606149, False, False, {})
# self._env.step(action) =  (array([-0.82231855, -0.56902736, -1.5399549 ], dtype=float32), -6.112413755847093, False, False, {})
# self._env.step(action) =  (array([-0.934189  , -0.35677844, -2.5555508 ], dtype=float32), -7.52562197016579, False, False, {})
# self._env.step(action) =  (array([-0.9975382 , -0.07012516, -3.1232455 ], dtype=float32), -9.267178592898173, False, False, {})
# self._env.step(action) =  (array([-0.96281445,  0.27016357, -3.5135834 ], dtype=float32), -10.396278948324445, False, False, {})
# self._env.step(action) =  (array([-0.8145376,  0.5801108, -3.3695254], dtype=float32), -8.49440113146664, False, False, {})
# self._env.step(action) =  (array([-0.61100084,  0.79162997, -2.7982035 ], dtype=float32), -6.5671349290797485, False, False, {})
# self._env.step(action) =  (array([-0.41941217,  0.9077959 , -2.0577753 ], dtype=float32), -5.0323388025173195, False, False, {})
# self._env.step(action) =  (array([-0.28885648,  0.9573724 , -1.1484232 ], dtype=float32), -3.964309075473959, False, False, {})
# self._env.step(action) =  (array([-0.2634039 ,  0.9646856 ,  0.10667957], dtype=float32), -3.3967740596123854, False, False, {})
# self._env.step(action) =  (array([-0.37852773,  0.92559   ,  1.5844638 ], dtype=float32), -3.60560876562336, False, False, {})
# self._env.step(action) =  (array([-0.61181146,  0.79100364,  3.1028914 ], dtype=float32), -4.831413683984166, False, False, {})
# self._env.step(action) =  (array([-0.8804356,  0.4741658,  4.5266023], dtype=float32), -7.340151098583337, False, False, {})
# self._env.step(action) =  (array([-0.99983925, -0.01792943,  5.166864  ], dtype=float32), -10.989745615951865, False, False, {})
# self._env.step(action) =  (array([-0.8674078, -0.4975979,  4.9883046], dtype=float32), -10.808692280343337, False, False, {})
# self._env.step(action) =  (array([-0.57791895, -0.81609416,  3.9410074 ], dtype=float32), -7.928889056937707, False, False, {})
# self._env.step(action) =  (array([-0.34806758, -0.9374694 ,  2.1628807 ], dtype=float32), -5.071607146154869, False, False, {})
# self._env.step(action) =  (array([-0.27187625, -0.96233225,  0.36032492], dtype=float32), -3.630786668169425, False, False, {})
# self._env.step(action) =  (array([-0.36492044, -0.93103874, -1.437951  ], dtype=float32), -3.535439544327422, False, False, {})
# self._env.step(action) =  (array([-0.59246147, -0.8055988 , -2.8793778 ], dtype=float32), -4.7918191056206005, False, False, {})
# self._env.step(action) =  (array([-0.8452009 , -0.53444874, -4.0872397 ], dtype=float32), -6.76989062920148, False, False, {})
# self._env.step(action) =  (array([-0.9973619, -0.0725899, -5.1392183], dtype=float32), -10.103958123787653, False, False, {})
# self._env.step(action) =  (array([-0.8959282,  0.4441989, -5.253367 ], dtype=float32), -11.588760033275403, False, False, {})
# self._env.step(action) =  (array([-0.6013933,  0.7989531, -4.389927 ], dtype=float32), -8.348143433271673, False, False, {})
# self._env.step(action) =  (array([-0.2994058,  0.9541259, -3.0717373], dtype=float32), -5.522181935281594, False, False, {})
# self._env.step(action) =  (array([-0.10732537,  0.99422395, -1.5817926 ], dtype=float32), -3.640318745155533, False, False, {})
# self._env.step(action) =  (array([-0.07884514,  0.99688685,  0.23383185], dtype=float32), -2.7518778328198112, False, False, {})
# self._env.step(action) =  (array([-0.22897463,  0.97343236,  1.7689788 ], dtype=float32), -3.100383643595618, False, False, {})
# self._env.step(action) =  (array([-0.46207458,  0.88684106,  2.733499  ], dtype=float32), -4.174848157815322, False, False, {})
# self._env.step(action) =  (array([-0.74565214,  0.66633546,  4.050294  ], dtype=float32), -5.893538588310132, False, False, {})
# self._env.step(action) =  (array([-0.97451216,  0.2243346 ,  5.235449  ], dtype=float32), -9.369611194172496, False, False, {})
# self._env.step(action) =  (array([-0.9539229, -0.3000518,  5.1576753], dtype=float32), -12.564437002885372, False, False, {})
# self._env.step(action) =  (array([-0.7299025 , -0.68355125,  4.2944226 ], dtype=float32), -8.953585071345683, False, False, {})
# self._env.step(action) =  (array([-0.46189076, -0.88693684,  2.96362   ], dtype=float32), -6.280408608207103, False, False, {})
# self._env.step(action) =  (array([-0.30729783, -0.95161337,  1.2841178 ], dtype=float32), -4.221598599832472, False, False, {})
# self._env.step(action) =  (array([-0.29636356, -0.9550752 , -0.2512371 ], dtype=float32), -3.479424444462696, False, False, {})
# self._env.step(action) =  (array([-0.4157083, -0.909498 , -1.5764104], dtype=float32), -3.7857119565122277, False, False, {})
# self._env.step(action) =  (array([-0.61686534, -0.7870687 , -2.5706177 ], dtype=float32), -4.9040251455642645, False, False, {})
# self._env.step(action) =  (array([-0.82762843, -0.5612764 , -3.265533  ], dtype=float32), -6.539803716140051, False, False, {})
# self._env.step(action) =  (array([-0.9732616 , -0.22969945, -3.7841763 ], dtype=float32), -8.626059208432057, False, False, {})
# self._env.step(action) =  (array([-0.9872308 ,  0.15929642, -3.8997884 ], dtype=float32), -11.199553691904033, False, False, {})
# self._env.step(action) =  (array([-0.8641061 ,  0.50330967, -3.6302304 ], dtype=float32), -9.199921987118499, False, False, {})
# self._env.step(action) =  (array([-0.6599024,  0.7513513, -3.0350897], dtype=float32), -7.138513033349919, False, False, {})
# self._env.step(action) =  (array([-0.46236  ,  0.8866923, -2.2303617], dtype=float32), -5.342632422992688, False, False, {})
# self._env.step(action) =  (array([-0.31629992,  0.94865924, -1.328882  ], dtype=float32), -4.180704229449638, False, False, {})
# self._env.step(action) =  (array([-0.26815295,  0.96337634, -0.21426843], dtype=float32), -3.497294297153928, False, False, {})
# self._env.step(action) =  (array([-0.33165443,  0.9434009 ,  0.96521115], dtype=float32), -3.475869913384194, False, False, {})
# self._env.step(action) =  (array([-0.5039766,  0.8637173,  2.2499702], dtype=float32), -4.187293108624075, False, False, {})
# self._env.step(action) =  (array([-0.74716413,  0.6646396 ,  3.4029922 ], dtype=float32), -5.883946297221641, False, False, {})
# self._env.step(action) =  (array([-0.948448  ,  0.31693283,  4.28083   ], dtype=float32), -8.237911911758465, False, False, {})
# self._env.step(action) =  (array([-0.9899663, -0.1413038,  4.6789746], dtype=float32), -11.420931201171737, False, False, {})
# self._env.step(action) =  (array([-0.8363188, -0.5482434,  4.193209 ], dtype=float32), -9.773354198509915, False, False, {})
# self._env.step(action) =  (array([-0.6091701, -0.7930396,  3.0400102], dtype=float32), -7.001716167168474, False, False, {})
# self._env.step(action) =  (array([-0.4322268, -0.9017649,  1.8274696], dtype=float32), -4.993839681939228, False, False, {})
# self._env.step(action) =  (array([-0.3547582 , -0.9349581 ,  0.39715654], dtype=float32), -3.9832645374208386, False, False, {})
# self._env.step(action) =  (array([-0.43544847, -0.90021366, -1.2575619 ], dtype=float32), -3.860727492417171, False, False, {})
# self._env.step(action) =  (array([-0.6313404 , -0.77550584, -2.6590004 ], dtype=float32), -4.897557235360686, False, False, {})
# self._env.step(action) =  (array([-0.86704963, -0.49822178, -4.0548983 ], dtype=float32), -6.912859335917345, False, True, {})
# self._env.step(action) =  (array([-0.99933016, -0.03659539, -4.976841  ], dtype=float32), -10.387409483588392, False, True, {})
# self._env.step(action) =  (array([-0.896287  ,  0.44347447, -4.873584  ], dtype=float32), -11.108463265641445, False, True, {})
# self._env.step(action) =  (array([-0.62950003,  0.7770005 , -4.0810704 ], dtype=float32), -8.080376789456666, False, True, {})
# self._env.step(action) =  (array([-0.3612809 ,  0.93245703, -2.6982234 ], dtype=float32), -5.552467127418897, False, True, {})
# self._env.step(action) =  (array([-0.2294309 ,  0.97332495, -0.93646187], dtype=float32), -3.7540959452635407, False, True, {})
# self._env.step(action) =  (array([-0.25433534,  0.9671161 ,  0.5509145 ], dtype=float32), -3.242514879327668, False, True, {})
# self._env.step(action) =  (array([-0.3916033,  0.9201342,  1.7698437], dtype=float32), -3.6809694124705103, False, True, {})
# self._env.step(action) =  (array([-0.6300415,  0.7765615,  3.2026505], dtype=float32), -4.946284300574335, False, True, {})
# self._env.step(action) =  (array([-0.8871663 ,  0.46144983,  4.235826  ], dtype=float32), -7.569598004231927, False, True, {})
# self._env.step(action) =  (array([-0.9993573 ,  0.03584641,  4.4913697 ], dtype=float32), -10.223522136377506, False, True, {})
# self._env.step(action) =  (array([-0.91792077, -0.39676368,  4.4444666 ], dtype=float32), -10.702527630006525, False, True, {})
# self._env.step(action) =  (array([-0.67608875, -0.73682016,  4.1098304 ], dtype=float32), -8.19362183547196, False, True, {})
# self._env.step(action) =  (array([-0.38921696, -0.9211461 ,  3.0461314 ], dtype=float32), -5.956679974506502, False, True, {})
# self._env.step(action) =  (array([-0.2026722, -0.9792466,  1.6809994], dtype=float32), -3.9554592615397257, False, True, {})
# self._env.step(action) =  (array([-0.12799864, -0.9917743 ,  0.4009678 ], dtype=float32), -3.0797113886070364, False, True, {})
# self._env.step(action) =  (array([-0.1994467, -0.9799087, -1.1349746], dtype=float32), -2.9508073101894006, False, True, {})
# self._env.step(action) =  (array([-0.4267889, -0.9043513, -2.8541434], dtype=float32), -3.8746168612958773, False, True, {})
# self._env.step(action) =  (array([-0.7412036 , -0.67128026, -4.1575665 ], dtype=float32), -6.21602760533607, False, True, {})
# self._env.step(action) =  (array([-0.9604295 , -0.27852333, -4.583211  ], dtype=float32), -8.937498651165148, False, True, {})
# self._env.step(action) =  (array([-0.9845955 ,  0.17484789, -4.642254  ], dtype=float32), -11.560090036593941, False, True, {})
# self._env.step(action) =  (array([-0.8105577,  0.5856588, -4.405599 ], dtype=float32), -9.596974799662998, False, True, {})
# self._env.step(action) =  (array([-0.52964205,  0.84822124, -3.6639788 ], dtype=float32), -7.007227227451635, False, True, {})
# self._env.step(action) =  (array([-0.28317484,  0.9590683 , -2.251093  ], dtype=float32), -4.890164206373214, False, True, {})
# self._env.step(action) =  (array([-0.18569252,  0.9826079 , -0.70316553], dtype=float32), -3.384527245671597, False, True, {})
# self._env.step(action) =  (array([-0.2068924 ,  0.9783637 ,  0.53004014], dtype=float32), -3.0734192716852355, False, True, {})
# self._env.step(action) =  (array([-0.34169587,  0.9398106 ,  1.6526177 ], dtype=float32), -3.5095339694161916, False, True, {})
# self._env.step(action) =  (array([-0.55615187,  0.8310807 ,  2.6879084 ], dtype=float32), -4.560718784970787, False, True, {})
# self._env.step(action) =  (array([-0.7991832,  0.6010875,  3.5308304], dtype=float32), -6.404727903678366, False, True, {})
# self._env.step(action) =  (array([-0.97142506,  0.23734649,  4.334063  ], dtype=float32), -8.634677121491439, False, True, {})
# self._env.step(action) =  (array([-0.9745084 , -0.22435105,  4.5730634 ], dtype=float32), -12.107664159628884, False, True, {})
# self._env.step(action) =  (array([-0.7985919 , -0.60187286,  4.160407  ], dtype=float32), -9.10316934691462, False, True, {})
# self._env.step(action) =  (array([-0.53662634, -0.84382   ,  3.213912  ], dtype=float32), -6.847289148178017, False, True, {})
# self._env.step(action) =  (array([-0.3552964, -0.9347537,  1.6652334], dtype=float32), -4.645035530572204, False, True, {})
# self._env.step(action) =  (array([-0.30172992, -0.95339346,  0.2274367 ], dtype=float32), -3.6494148855363426, False, True, {})
# self._env.step(action) =  (array([-0.37849858, -0.9256019 , -1.178541  ], dtype=float32), -3.6308561983483387, False, True, {})
# self._env.step(action) =  (array([-0.571841 , -0.8203645, -2.5247228], dtype=float32), -4.572096077944761, False, True, {})
# self._env.step(action) =  (array([-0.8086642 , -0.58827055, -3.549015  ], dtype=float32), -6.423202212232935, False, True, {})
# self._env.step(action) =  (array([-0.9743208 , -0.22516431, -4.151815  ], dtype=float32), -8.836154920589285, False, True, {})
# self._env.step(action) =  (array([-0.9807796 ,  0.19511887, -4.197481  ], dtype=float32), -11.610589240807652, False, True, {})
# self._env.step(action) =  (array([-0.82979995,  0.55806094, -3.947194  ], dtype=float32), -9.121769793585518, False, True, {})
# self._env.step(action) =  (array([-0.5736998,  0.8190657, -3.5566113], dtype=float32), -7.014098054393126, False, True, {})
# self._env.step(action) =  (array([-0.31589055,  0.9487956 , -2.5630474 ], dtype=float32), -5.124673682845368, False, True, {})
# self._env.step(action) =  (array([-0.17757335,  0.98410755, -0.9968867 ], dtype=float32), -3.5839564926969585, False, True, {})
# self._env.step(action) =  (array([-0.20902574,  0.97791016,  0.7667773 ], dtype=float32), -3.040799343339194, False, True, {})
# self._env.step(action) =  (array([-0.40495932,  0.9143347 ,  2.4734235 ], dtype=float32), -3.748647400559788, False, True, {})
# self._env.step(action) =  (array([-0.7022051,  0.7119747,  3.9701862], dtype=float32), -5.689504733307628, False, True, {})
# self._env.step(action) =  (array([-0.9472937,  0.3203665,  4.737728 ], dtype=float32), -8.755078259795097, False, True, {})
# self._env.step(action) =  (array([-0.99053365, -0.13727011,  4.547061  ], dtype=float32), -11.553819086526378, False, True, {})
# self._env.step(action) =  (array([-0.8544499 , -0.51953375,  3.977346  ], dtype=float32), -9.566882211133171, False, True, {})
# self._env.step(action) =  (array([-0.63966054, -0.76865757,  2.9829426 ], dtype=float32), -7.1429235915682145, False, True, {})
# self._env.step(action) =  (array([-0.4773432 , -0.87871695,  1.6661086 ], dtype=float32), -5.141852699668387, False, True, {})
# self._env.step(action) =  (array([-0.42656854, -0.90445524,  0.10097168], dtype=float32), -4.1771204785324265, False, True, {})
# self._env.step(action) =  (array([-0.5397723 , -0.84181106, -1.7520475 ], dtype=float32), -4.289193846950794, False, True, {})
# self._env.step(action) =  (array([-0.7551825 , -0.65551454, -3.081597  ], dtype=float32), -5.85927574685493, False, True, {})
# self._env.step(action) =  (array([-0.9356662 , -0.35288632, -3.6358218 ], dtype=float32), -7.946467590731415, False, True, {})
# self._env.step(action) =  (array([-0.9998008,  0.0199594, -3.911534 ], dtype=float32), -10.166864405127992, False, True, {})
# self._env.step(action) =  (array([-0.9148787 ,  0.40372872, -3.9362621 ], dtype=float32), -10.124624601079738, False, True, {})
# self._env.step(action) =  (array([-0.71657264,  0.69751245, -3.370423  ], dtype=float32), -7.853403904514545, False, True, {})
# self._env.step(action) =  (array([-0.52088726,  0.8536255 , -2.1326315 ], dtype=float32), -5.786699473802719, False, True, {})
# self._env.step(action) =  (array([-0.4248178 ,  0.90527886, -0.8496304 ], dtype=float32), -4.390003231794819, False, True, {})
# self._env.step(action) =  (array([-0.42917085,  0.90322334,  0.44843936], dtype=float32), -3.980861681120895, False, True, {})
# self._env.step(action) =  (array([-0.5564114,  0.8309069,  1.6877286], dtype=float32), -4.467951896140548, False, True, {})
# self._env.step(action) =  (array([-0.7300972,  0.6833433,  2.4675617], dtype=float32), -5.577377237534501, False, True, {})
# self._env.step(action) =  (array([-0.9012341,  0.4333325,  3.3117754], dtype=float32), -7.158294539269941, False, True, {})
# self._env.step(action) =  (array([-0.9983745 ,  0.05699431,  4.077782  ], dtype=float32), -9.702010060598836, False, True, {})
# self._env.step(action) =  (array([-0.92938435, -0.3691135 ,  4.4422245 ], dtype=float32), -10.732312647533412, False, True, {})
# self._env.step(action) =  (array([-0.69804525, -0.71605366,  3.936829  ], dtype=float32), -8.44698150809421, False, True, {})
# self._env.step(action) =  (array([-0.4680924, -0.8836795,  2.4144824], dtype=float32), -5.836147070745284, False, True, {})
# self._env.step(action) =  (array([-0.3777214 , -0.9259193 ,  0.51025206], dtype=float32), -4.159262747886849, False, True, {})
# self._env.step(action) =  (array([-0.44405654, -0.8959988 , -0.9831068 ], dtype=float32), -3.9511122366738394, False, True, {})
# self._env.step(action) =  (array([-0.594979 , -0.8037412, -2.0643394], dtype=float32), -4.648876072750197, False, True, {})
# self._env.step(action) =  (array([-0.8025747 , -0.59655166, -3.2793045 ], dtype=float32), -6.149129104791671, False, True, {})
# self._env.step(action) =  (array([-0.97283334, -0.23150648, -4.252957  ], dtype=float32), -8.753750492465851, False, True, {})
# self._env.step(action) =  (array([-0.9771672 ,  0.21247186, -4.457235  ], dtype=float32), -11.837376686982473, False, True, {})
# self._env.step(action) =  (array([-0.8148391,  0.5796872, -3.8336313], dtype=float32), -9.178610998959064, False, True, {})
# self._env.step(action) =  (array([-0.59644455,  0.8026543 , -2.9760613 ], dtype=float32), -6.648838055115973, False, True, {})
# self._env.step(action) =  (array([-0.40937772,  0.912365  , -1.7583809 ], dtype=float32), -4.999276214669905, False, True, {})
# self._env.step(action) =  (array([-0.34816164,  0.9374345 , -0.423556  ], dtype=float32), -3.8762021096320294, False, True, {})
# self._env.step(action) =  (array([-0.38748798,  0.92187476,  0.78764504], dtype=float32), -3.722644619538592, False, True, {})
# self._env.step(action) =  (array([-0.55380523,  0.83264625,  2.2743316 ], dtype=float32), -4.405252890270749, False, True, {})
# self._env.step(action) =  (array([-0.785193 ,  0.6192511,  3.3221567], dtype=float32), -6.227540480307889, False, True, {})
# self._env.step(action) =  (array([-0.9540592 ,  0.29961827,  3.7160375 ], dtype=float32), -8.29507049376132, False, True, {})
# self._env.step(action) =  (array([-0.99789566, -0.0648404 ,  3.633695  ], dtype=float32), -10.55737519990073, False, True, {})
# self._env.step(action) =  (array([-0.92087483, -0.38985837,  3.3303518 ], dtype=float32), -9.59844046989731, False, True, {})
# self._env.step(action) =  (array([-0.77537453, -0.6315017 ,  2.4995143 ], dtype=float32), -7.674394807011437, False, True, {})
# self._env.step(action) =  (array([-0.6689505 , -0.74330693,  1.328091  ], dtype=float32), -5.927752977321957, False, True, {})
# self._env.step(action) =  (array([-0.6138254 , -0.7894418 ,  0.57846177], dtype=float32), -5.188196592118996, False, True, {})
# self._env.step(action) =  (array([-0.60428476, -0.7967684 , -0.04326257], dtype=float32), -4.928642779934593, False, True, {})
# self._env.step(action) =  (array([-0.6555788, -0.7551268, -0.9522241], dtype=float32), -5.022890624181961, False, True, {})
# self._env.step(action) =  (array([-0.77933025, -0.6266134 , -2.060655  ], dtype=float32), -5.804742925536945, False, True, {})
# self._env.step(action) =  (array([-0.9247876 , -0.38048384, -3.1862202 ], dtype=float32), -7.371854006037721, False, True, {})
# self._env.step(action) =  (array([-0.99970627, -0.02423652, -3.606979  ], dtype=float32), -10.008851020861934, False, True, {})
# self._env.step(action) =  (array([-0.94968724,  0.31319988, -3.490858  ], dtype=float32), -10.120287027397692, False, True, {})
# self._env.step(action) =  (array([-0.8036112,  0.5951546, -2.8886235], dtype=float32), -8.235123661073807, False, True, {})
# self._env.step(action) =  (array([-0.66669136,  0.7453339 , -1.8750236 ], dtype=float32), -6.2167599973753545, False, True, {})
# self._env.step(action) =  (array([-0.5715888 ,  0.82054025, -0.9221428 ], dtype=float32), -5.17844344919457, False, True, {})
# self._env.step(action) =  (array([-0.56659406,  0.8239971 ,  0.19813007], dtype=float32), -4.690378176829505, False, True, {})
# self._env.step(action) =  (array([-0.64045995,  0.76799154,  1.1429135 ], dtype=float32), -4.930521318703605, False, True, {})
# self._env.step(action) =  (array([-0.76663584,  0.64208215,  2.0221276 ], dtype=float32), -5.730630426702986, False, True, {})
# self._env.step(action) =  (array([-0.9020955 ,  0.43153647,  2.579272  ], dtype=float32), -7.185685799222266, False, True, {})
# self._env.step(action) =  (array([-0.9836011 ,  0.18035758,  2.6637304 ], dtype=float32), -8.687412380046625, False, True, {})
# self._env.step(action) =  (array([-0.99707353, -0.07644819,  2.5599358 ], dtype=float32), -10.223802966956208, False, True, {})
# self._env.step(action) =  (array([-0.9522288 , -0.30538556,  2.2499828 ], dtype=float32), -9.254447063256826, False, True, {})
# self._env.step(action) =  (array([-0.87604356, -0.48223203,  1.8652322 ], dtype=float32), -7.8600225712246115, False, True, {})
# self._env.step(action) =  (array([-0.79748976, -0.60333246,  1.2136611 ], dtype=float32), -6.80691744131756, False, True, {})
# self._env.step(action) =  (array([-0.77190256, -0.6357409 ,  0.11146666], dtype=float32), -6.094522262949006, False, True, {})
# self._env.step(action) =  (array([-0.8087059 , -0.5882132 , -0.70767945], dtype=float32), -6.164557818887156, False, True, {})
# self._env.step(action) =  (array([-0.8710876, -0.4911277, -1.4098241], dtype=float32), -6.623237749327344, False, True, {})
# self._env.step(action) =  (array([-0.9495003, -0.313766 , -2.0094445], dtype=float32), -7.761988596110314, False, True, {})
# self._env.step(action) =  (array([-0.99605346, -0.08875525, -2.5321424 ], dtype=float32), -8.996052780730846, False, True, {})
# self._env.step(action) =  (array([-0.98267496,  0.18533745, -2.6088083 ], dtype=float32), -10.362957132563576, False, True, {})
# self._env.step(action) =  (array([-0.9175249 ,  0.39767838, -2.2277656 ], dtype=float32), -8.584997152759822, False, True, {})
# self._env.step(action) =  (array([-0.8283981,  0.5601398, -1.5578299], dtype=float32), -7.3562915419506805, False, True, {})
# self._env.step(action) =  (array([-0.7795162 ,  0.62638205, -0.7344906 ], dtype=float32), -6.343574654223286, False, True, {})
# self._env.step(action) =  (array([-0.7624101 ,  0.64709413, -0.00255669], dtype=float32), -5.9723079262896235, False, True, {})
# self._env.step(action) =  (array([-0.80502903,  0.59323543,  0.84422255], dtype=float32), -6.101951485004756, False, True, {})
# self._env.step(action) =  (array([-0.8803053,  0.4744076,  1.6819314], dtype=float32), -6.699394536058691, False, True, {})
# self._env.step(action) =  (array([-0.96899915,  0.24706407,  2.7168603 ], dtype=float32), -8.072554675176699, False, True, {})
# self._env.step(action) =  (array([-0.9976723 , -0.06819078,  3.1968267 ], dtype=float32), -10.301730262153704, False, True, {})
# self._env.step(action) =  (array([-0.9341977 , -0.35675564,  2.8181033 ], dtype=float32), -9.48273387055439, False, True, {})
# self._env.step(action) =  (array([-0.8347325 , -0.55065566,  1.9448562 ], dtype=float32), -7.640130737146307, False, True, {})
# self._env.step(action) =  (array([-0.76934665, -0.6388315 ,  0.79188144], dtype=float32), -6.389592031699776, False, True, {})
# self._env.step(action) =  (array([-0.78170484, -0.6236486 , -0.5473887 ], dtype=float32), -5.96218333755779, False, True, {})
# self._env.step(action) =  (array([-0.8648942, -0.5019542, -1.7161381], dtype=float32), -6.553117681232389, False, True, {})
# self._env.step(action) =  (array([-0.95553184, -0.2948879 , -2.3870592 ], dtype=float32), -7.873737259004995, False, True, {})
# self._env.step(action) =  (array([-0.99959165, -0.02857504, -2.8681366 ], dtype=float32), -9.468961787943655, False, True, {})
# self._env.step(action) =  (array([-0.9661126 ,  0.25812083, -2.7108095 ], dtype=float32), -10.050079773567955, False, True, {})
# self._env.step(action) =  (array([-0.8924144,  0.4512167, -1.9014009], dtype=float32), -8.166565167654161, False, True, {})
# self._env.step(action) =  (array([-0.83226055,  0.5543847 , -0.89179885], dtype=float32), -6.9790683844768635, False, True, {})
# self._env.step(action) =  (array([-0.8328057 ,  0.55356544,  0.27693594], dtype=float32), -6.464381587271248, False, True, {})
# self._env.step(action) =  (array([-0.88884777,  0.45820263,  1.410831  ], dtype=float32), -6.800961504724608, False, True, {})
# self._env.step(action) =  (array([-0.96870726,  0.24820614,  2.5298674 ], dtype=float32), -8.03397110464881, False, True, {})
# self._env.step(action) =  (array([-0.99872637, -0.05045447,  3.0295248 ], dtype=float32), -10.143215738044029, False, True, {})
# self._env.step(action) =  (array([-0.9460303, -0.3240781,  2.6421895], dtype=float32), -9.535972822997033, False, True, {})
# self._env.step(action) =  (array([-0.8559418, -0.5170722,  2.0280309], dtype=float32), -7.7898473942671576, False, True, {})
# self._env.step(action) =  (array([-0.770131  , -0.63788575,  1.2171383 ], dtype=float32), -6.609983853386503, False, True, {})
# self._env.step(action) =  (array([-0.74616915, -0.6657564 ,  0.08620441], dtype=float32), -5.8861073839775635, False, True, {})
# self._env.step(action) =  (array([-0.78329057, -0.62165576, -0.6740969 ], dtype=float32), -5.965822893028505, False, True, {})
# self._env.step(action) =  (array([-0.8425943 , -0.53854877, -1.1931063 ], dtype=float32), -6.388915860734078, False, True, {})
# self._env.step(action) =  (array([-0.91589177, -0.4014253 , -1.6132857 ], dtype=float32), -7.23859949454022, False, True, {})
# self._env.step(action) =  (array([-0.97343636, -0.22895777, -1.9686532 ], dtype=float32), -8.18811050846759, False, True, {})
# self._env.step(action) =  (array([-0.99997526,  0.00703052, -2.567018  ], dtype=float32), -9.606838038193818, False, True, {})
# self._env.step(action) =  (array([-0.9583519 ,  0.28558996, -2.807563  ], dtype=float32), -9.763384539787094, False, True, {})
# self._env.step(action) =  (array([-0.8592107 ,  0.51162183, -2.2808    ], dtype=float32), -8.102778676877719, False, True, {})
# self._env.step(action) =  (array([-0.75733644,  0.6530249 , -1.6724164 ], dtype=float32), -6.6526381780614265, False, True, {})
# self._env.step(action) =  (array([-0.6789734 ,  0.73416287, -0.77913606], dtype=float32), -5.771022502065554, False, True, {})
# self._env.step(action) =  (array([-0.7046814 ,  0.7095239 ,  0.77214545], dtype=float32), -5.359192536218283, False, True, {})
# self._env.step(action) =  (array([-0.819089 ,  0.5736665,  1.9727217], dtype=float32), -6.165955117412909, False, True, {})
# self._env.step(action) =  (array([-0.93343717,  0.35874093,  2.5783126 ], dtype=float32), -7.530627963193772, False, True, {})
# self._env.step(action) =  (array([-0.99639416,  0.08484531,  2.8733857 ], dtype=float32), -9.25070045241391, False, True, {})
# self._env.step(action) =  (array([-0.9795069, -0.2014106,  2.8805125], dtype=float32), -10.33010727204396, False, True, {})
# self._env.step(action) =  (array([-0.89799064, -0.44001457,  2.2767136 ], dtype=float32), -8.614400447147784, False, True, {})
# self._env.step(action) =  (array([-0.82994235, -0.5578492 ,  1.0283811 ], dtype=float32), -7.057208897675561, False, True, {})
# self._env.step(action) =  (array([-0.82497835, -0.5651643 , -0.15224805], dtype=float32), -6.428802592894051, False, True, {})
# self._env.step(action) =  (array([-0.86438465, -0.50283116, -0.84637403], dtype=float32), -6.658351693625763, False, True, {})
# self._env.step(action) =  (array([-0.92140734, -0.3885981 , -1.5184221 ], dtype=float32), -7.218902483897158, False, True, {})
# self._env.step(action) =  (array([-0.9837835 , -0.17935999, -2.4270124 ], dtype=float32), -8.447623952196048, False, True, {})
# self._env.step(action) =  (array([-0.9943185 ,  0.10644585, -2.9224417 ], dtype=float32), -10.41707343271978, False, True, {})
# self._env.step(action) =  (array([-0.929114  ,  0.36979347, -2.5245583 ], dtype=float32), -9.20000679290867, False, True, {})
# self._env.step(action) =  (array([-0.8499215,  0.5269093, -1.4824997], dtype=float32), -7.498174874390859, False, True, {})
# self._env.step(action) =  (array([-0.8137662 ,  0.58119243, -0.4289235 ], dtype=float32), -6.542781864753078, False, True, {})
# self._env.step(action) =  (array([-0.8250644,  0.5650386,  0.36318  ], dtype=float32), -6.365861440582693, False, True, {})
# self._env.step(action) =  (array([-0.86440265,  0.5028002 ,  0.7887865 ], dtype=float32), -6.683002794565077, False, True, {})
# self._env.step(action) =  (array([-0.91624486,  0.40061876,  1.4246694 ], dtype=float32), -7.143148720548479, False, True, {})
# self._env.step(action) =  (array([-0.9778827 ,  0.20915417,  2.0966449 ], dtype=float32), -8.360421665516517, False, True, {})
# self._env.step(action) =  (array([-0.99999326, -0.00366244,  2.1030388 ], dtype=float32), -9.72049180595042, False, True, {})
# self._env.step(action) =  (array([-0.9809005 , -0.19451004,  1.8989737 ], dtype=float32), -9.623907874970246, False, True, {})
# self._env.step(action) =  (array([-0.93085027, -0.36540076,  1.7814999 ], dtype=float32), -8.480589131932687, False, True, {})
# self._env.step(action) =  (array([-0.8586282 , -0.51259893,  1.5677103 ], dtype=float32), -7.487604868450574, False, True, {})
# self._env.step(action) =  (array([-0.78992647, -0.61320156,  1.0693539 ], dtype=float32), -6.614029353017556, False, True, {})
# self._env.step(action) =  (array([-0.7565879 , -0.653892  ,  0.31442326], dtype=float32), -6.030633952995604, False, True, {})
# self._env.step(action) =  (array([-0.7711893 , -0.6366059 , -0.33465093], dtype=float32), -5.932747901300206, False, True, {})
# self._env.step(action) =  (array([-0.8128299, -0.5825011, -0.8239551], dtype=float32), -6.174204673664316, False, True, {})
# self._env.step(action) =  (array([-0.8830581 , -0.46926367, -1.585519  ], dtype=float32), -6.742147947400982, False, True, {})
# self._env.step(action) =  (array([-0.96701187, -0.2547313 , -2.579437  ], dtype=float32), -8.008740696968683, False, True, {})
# self._env.step(action) =  (array([-0.9987637,  0.0497105, -3.1171362], dtype=float32), -10.131474005190688, False, True, {})
# self._env.step(action) =  (array([-0.93667185,  0.3502083 , -3.072586  ], dtype=float32), -9.583292334967803, False, True, {})
# self._env.step(action) =  (array([-0.8007223 ,  0.59903574, -2.7441432 ], dtype=float32), -7.820145232214402, False, True, {})
# self._env.step(action) =  (array([-0.6405818,  0.7678899, -2.2088757], dtype=float32), -6.254226956136664, False, True, {})
# self._env.step(action) =  (array([-0.500927  ,  0.86548954, -1.506445  ], dtype=float32), -5.077484072139868, False, True, {})
# self._env.step(action) =  (array([-0.43222135,  0.90176755, -0.4767976 ], dtype=float32), -4.28439749700567, False, True, {})
# self._env.step(action) =  (array([-0.4789515 ,  0.87784135,  0.91828156], dtype=float32), -4.10025932958879, False, True, {})
# self._env.step(action) =  (array([-0.63301826,  0.7741369 ,  2.0307727 ], dtype=float32), -4.931583720197637, False, True, {})
# self._env.step(action) =  (array([-0.8111441,  0.5848464,  2.8857307], dtype=float32), -6.171073809025329, False, True, {})
# self._env.step(action) =  (array([-0.9626862,  0.2706202,  3.651988 ], dtype=float32), -8.338745244341705, False, True, {})
# self._env.step(action) =  (array([-0.99355066, -0.11338901,  3.9382503 ], dtype=float32), -10.808991686867552, False, True, {})
# self._env.step(action) =  (array([-0.88363504, -0.46817636,  3.5579395 ], dtype=float32), -9.554311117240477, False, True, {})
# self._env.step(action) =  (array([-0.7120997, -0.7020784,  2.7425716], dtype=float32), -7.200721657120889, False, True, {})
# self._env.step(action) =  (array([-0.55477494, -0.83200043,  1.7597961 ], dtype=float32), -5.590453292761188, False, True, {})
# self._env.step(action) =  (array([-0.47175375, -0.8817304 ,  0.7837016 ], dtype=float32), -4.551572931041945, False, True, {})
# self._env.step(action) =  (array([-0.4772297, -0.8787786, -0.5248786], dtype=float32), -4.188950741849952, False, True, {})
# self._env.step(action) =  (array([-0.62299484, -0.78222597, -2.0602658 ], dtype=float32), -4.788762036456875, False, True, {})
# self._env.step(action) =  (array([-0.81709796, -0.57649887, -3.041329  ], dtype=float32), -6.33569995559115, False, True, {})
# self._env.step(action) =  (array([-0.9622722, -0.2720886, -3.4172149], dtype=float32), -8.396246156341814, False, True, {})
# self._env.step(action) =  (array([-0.9982968 ,  0.05833945, -3.3242936 ], dtype=float32), -10.329398499336934, False, True, {})
# self._env.step(action) =  (array([-0.92833155,  0.3717533 , -3.2807944 ], dtype=float32), -9.562072175380171, False, True, {})
# self._env.step(action) =  (array([-0.76812536,  0.6402995 , -3.0053701 ], dtype=float32), -7.817107345912298, False, True, {})
# self._env.step(action) =  (array([-0.5929858,  0.8052129, -2.1782942], dtype=float32), -6.056519459063085, False, True, {})
# self._env.step(action) =  (array([-0.47151494,  0.88185805, -1.2150464 ], dtype=float32), -4.782485154760872, False, True, {})
# self._env.step(action) =  (array([-0.42943496,  0.9030978 , -0.19544922], dtype=float32), -4.154860190348762, False, True, {})
# self._env.step(action) =  (array([-0.49066967,  0.8713457 ,  1.0201728 ], dtype=float32), -4.144589085716536, False, True, {})
# self._env.step(action) =  (array([-0.6453527,  0.7638847,  2.1097536], dtype=float32), -4.972820508832943, False, True, {})
# self._env.step(action) =  (array([-0.83042496,  0.55713046,  3.0587564 ], dtype=float32), -6.378661441573862, False, True, {})
# self._env.step(action) =  (array([-0.9743533 ,  0.22502358,  3.7606182 ], dtype=float32), -8.672507604304656, False, True, {})
# self._env.step(action) =  (array([-0.984571  , -0.17498553,  4.188116  ], dtype=float32), -11.160943274766659, False, True, {})
# self._env.step(action) =  (array([-0.83236665, -0.5542253 ,  3.8800075 ], dtype=float32), -9.446837887573734, False, True, {})
# self._env.step(action) =  (array([-0.6188912 , -0.78547674,  3.0396261 ], dtype=float32), -6.792402612404468, False, True, {})
# self._env.step(action) =  (array([-0.41279945, -0.9108219 ,  2.1149626 ], dtype=float32), -5.159227183011712, False, True, {})
# self._env.step(action) =  (array([-0.30846557, -0.95123553,  0.76662165], dtype=float32), -3.913568036556554, False, True, {})
# self._env.step(action) =  (array([-0.34303638, -0.9393221 , -0.78291625], dtype=float32), -3.5420745112389014, False, True, {})
# self._env.step(action) =  (array([-0.5183425, -0.8551731, -2.2874222], dtype=float32), -4.2638705653188484, False, True, {})
# self._env.step(action) =  (array([-0.768782 , -0.6395109, -3.7136457], dtype=float32), -5.975425746235061, False, True, {})
# self._env.step(action) =  (array([-0.9739947, -0.226571 , -4.9038467], dtype=float32), -9.05653027491207, False, True, {})
# self._env.step(action) =  (array([-0.9564043,  0.2920459, -5.265245 ], dtype=float32), -12.401462790650122, False, True, {})
# self._env.step(action) =  (array([-0.6994868,  0.7146455, -4.8919344], dtype=float32), -9.31411017474695, False, True, {})
# self._env.step(action) =  (array([-0.35941002,  0.93317974, -3.6031032 ], dtype=float32), -6.551396796756337, False, True, {})
# self._env.step(action) =  (array([-0.14786346,  0.9890078 , -1.7757472 ], dtype=float32), -3.9499037344942116, False, True, {})
# self._env.step(action) =  (array([-0.08895507,  0.99603564, -0.25676885], dtype=float32), -2.8846637060962093, False, True, {})
# self._env.step(action) =  (array([-0.1731582 ,  0.98489404,  1.2819439 ], dtype=float32), -2.842914295662768, False, True, {})
# self._env.step(action) =  (array([-0.4014594,  0.9158768,  2.6417081], dtype=float32), -3.8892294378946044, False, True, {})
# self._env.step(action) =  (array([-0.6820847,  0.7312732,  3.6400313], dtype=float32), -5.544702416217736, False, True, {})
# self._env.step(action) =  (array([-0.92063653,  0.3904208 ,  4.295399  ], dtype=float32), -8.051569731567882, False, True, {})
# self._env.step(action) =  (array([-0.99962777, -0.02728192,  4.2036715 ], dtype=float32), -10.662062032774422, False, True, {})
# self._env.step(action) =  (array([-0.91461724, -0.40432075,  3.8923504 ], dtype=float32), -10.03815766847741, False, True, {})
# self._env.step(action) =  (array([-0.71680623, -0.6972724 ,  3.3473306 ], dtype=float32), -7.8517736777833145, False, True, {})
# self._env.step(action) =  (array([-0.51109433, -0.8595246 ,  2.4169285 ], dtype=float32), -5.7712596272153505, False, True, {})
# self._env.step(action) =  (array([-0.37135607, -0.9284905 ,  1.1749667 ], dtype=float32), -4.418748740952758, False, True, {})
# self._env.step(action) =  (array([-0.36614648, -0.93055725, -0.27548632], dtype=float32), -3.7472734022451646, False, True, {})
# self._env.step(action) =  (array([-0.4857544, -0.8740953, -1.7123959], dtype=float32), -4.057445834857199, False, True, {})
# self._env.step(action) =  (array([-0.7094467 , -0.70475906, -3.1685321 ], dtype=float32), -5.450974779036134, False, True, {})
# self._env.step(action) =  (array([-0.9317943, -0.3629868, -4.4137073], dtype=float32), -7.944227396077995, False, True, {})
# self._env.step(action) =  (array([-0.9926622 ,  0.12092048, -4.9712625 ], dtype=float32), -11.469571589052244, False, True, {})
# self._env.step(action) =  (array([-0.8294917,  0.5585191, -4.55357  ], dtype=float32), -10.085692257309303, False, True, {})
# self._env.step(action) =  (array([-0.5567002 ,  0.83071345, -3.673942  ], dtype=float32), -7.165430305903295, False, True, {})
# self._env.step(action) =  (array([-0.29097012,  0.95673215, -2.7240481 ], dtype=float32), -5.022030636531856, False, True, {})
# self._env.step(action) =  (array([-0.10605206,  0.99436057, -1.5472608 ], dtype=float32), -3.576492057243645, False, True, {})
# self._env.step(action) =  (array([-0.04731281,  0.99888015, -0.3247995 ], dtype=float32), -2.746167287985941, False, True, {})
# self._env.step(action) =  (array([-0.11800268,  0.99301326,  1.2142516 ], dtype=float32), -2.6587759650356766, False, True, {})
# self._env.step(action) =  (array([-0.36650485,  0.93041617,  2.919627  ], dtype=float32), -3.7330260792053798, False, True, {})
# self._env.step(action) =  (array([-0.6986061,  0.7155065,  4.377066 ], dtype=float32), -5.804897526707273, False, True, {})
# self._env.step(action) =  (array([-0.9669074 ,  0.25512758,  5.7210975 ], dtype=float32), -9.317193646521542, False, True, {})
# self._env.step(action) =  (array([-0.9410299 , -0.33832335,  5.8832254 ], dtype=float32), -13.372955426177178, False, True, {})
# self._env.step(action) =  (array([-0.6444485, -0.7646477,  5.135336 ], dtype=float32), -9.27748817394751, False, True, {})
# self._env.step(action) =  (array([-0.26312232, -0.9647625 ,  3.92363   ], dtype=float32), -6.398372325237665, False, True, {})
# self._env.step(action) =  (array([ 0.00258881, -0.99999666,  2.339269  ], dtype=float32), -3.7626300347431125, False, True, {})
# self._env.step(action) =  (array([ 0.1426635 , -0.98977125,  1.175272  ], dtype=float32), -2.480706104635775, False, True, {})
# self._env.step(action) =  (array([ 0.17056818, -0.9853459 , -0.15446919], dtype=float32), -1.9893343907100351, False, True, {})
# self._env.step(action) =  (array([ 0.0196644 , -0.99980664, -2.0053074 ], dtype=float32), -2.21337359214065, False, True, {})
# self._env.step(action) =  (array([-0.30879796, -0.95112765, -3.6855402 ], dtype=float32), -3.7834423621461073, False, True, {})
# self._env.step(action) =  (array([-0.6993968, -0.7147336, -4.8581166], dtype=float32), -6.3172276623996115, False, True, {})
# self._env.step(action) =  (array([-0.9684914, -0.2490472, -5.639501 ], dtype=float32), -9.559011763026732, False, True, {})
# self._env.step(action) =  (array([-0.9469835 ,  0.32128215, -5.742759  ], dtype=float32), -13.022568115591122, False, True, {})
# self._env.step(action) =  (array([-0.6517031,  0.7584742, -5.236031 ], dtype=float32), -9.427213340770974, False, True, {})
# self._env.step(action) =  (array([-0.2531938,  0.9674156, -4.1924567], dtype=float32), -6.532771909116374, False, True, {})
# self._env.step(action) =  (array([ 0.04244258,  0.9990989 , -2.5236893 ], dtype=float32), -3.92561654015055, False, True, {})
# self._env.step(action) =  (array([ 0.17817053,  0.9839996 , -1.1330259 ], dtype=float32), -2.3571729840058, False, True, {})
# self._env.step(action) =  (array([0.20243672, 0.9792954 , 0.17765634], dtype=float32), -1.8901150315359707, False, True, {})
# self._env.step(action) =  (array([0.07192361, 0.9974101 , 1.6084764 ], dtype=float32), -2.1188070237706547, False, True, {})
# self._env.step(action) =  (array([-0.17074311,  0.98531556,  2.6764057 ], dtype=float32), -3.072454368640525, False, True, {})
# self._env.step(action) =  (array([-0.5039827 ,  0.86371374,  3.9850528 ], dtype=float32), -4.600346825043004, False, True, {})
# self._env.step(action) =  (array([-0.85484207,  0.5188883 ,  5.1800947 ], dtype=float32), -7.728879433105188, False, True, {})
# self._env.step(action) =  (array([-0.99991834, -0.01278064,  5.7184124 ], dtype=float32), -11.196522462735176, False, True, {})
# self._env.step(action) =  (array([-0.8333617 , -0.55272806,  5.680349  ], dtype=float32), -11.403218198962241, False, True, {})
# self._env.step(action) =  (array([-0.44666559, -0.894701  ,  5.0503078 ], dtype=float32), -8.13723232704505, False, True, {})
# self._env.step(action) =  (array([-0.02709964, -0.9996327 ,  4.1152353 ], dtype=float32), -5.374921646739247, False, True, {})
# self._env.step(action) =  (array([ 0.297754  , -0.95464265,  2.981743  ], dtype=float32), -3.3111440493254602, False, True, {})
# self._env.step(action) =  (array([ 0.48287833, -0.8756875 ,  1.6503757 ], dtype=float32), -1.8883733727429641, False, True, {})
# self._env.step(action) =  (array([ 0.54009837, -0.8416019 ,  0.3855553 ], dtype=float32), -1.129323309233763, False, True, {})
# self._env.step(action) =  (array([ 0.49884564, -0.8666909 , -0.79780376], dtype=float32), -1.0201759400674928, False, True, {})
# self._env.step(action) =  (array([ 0.3445718, -0.93876  , -1.9665793], dtype=float32), -1.4652111091811424, False, True, {})
# self._env.step(action) =  (array([ 0.05856442, -0.9982836 , -3.3448586 ], dtype=float32), -2.44375944813987, False, True, {})
# self._env.step(action) =  (array([-0.38293657, -0.92377466, -4.8427796 ], dtype=float32), -4.718822085933856, False, True, {})
# self._env.step(action) =  (array([-0.82090884, -0.5710593 , -5.9522877 ], dtype=float32), -7.969199316886848, False, True, {})
# self._env.step(action) =  (array([-0.9988802 ,  0.04731075, -6.8078847 ], dtype=float32), -12.080210314494051, False, True, {})
# self._env.step(action) =  (array([-0.73162746,  0.6817047 , -6.9862103 ], dtype=float32), -12.511121440150353, False, True, {})
# ...
# self._env.step(action) =  (array([-0.89743   , -0.44115686,  0.35292408], dtype=float32), -7.400592196338091, False, True, {})
# self._env.step(action) =  (array([-0.9194313 , -0.39325064, -0.77906764], dtype=float32), -7.290824381181906, False, True, {})
# self._env.step(action) =  (array([-0.9665526, -0.2564685, -1.6398406], dtype=float32), -7.999874154373037, False, True, {})
# self._env.step(action) =  (array([-0.99808073, -0.06192577, -1.983183  ], dtype=float32), -9.269713004618156, False, True, {})
# self._env.step(action) =  (array([-0.9916883 ,  0.12866339, -1.8920833 ], dtype=float32), -10.026127441517643, False, True, {})
# self._env.step(action) =  (array([-0.95729375,  0.28911713, -1.4998374 ], dtype=float32), -8.86516393664705, False, True, {})
# self._env.step(action) =  (array([-0.92084056,  0.38993925, -0.98578024], dtype=float32), -7.920611169457391, False, True, {})
# self._env.step(action) =  (array([-0.8992314 ,  0.43747333, -0.26669127], dtype=float32), -7.363686969087297, False, True, {})
# self._env.step(action) =  (array([-0.9128645,  0.4082627,  0.3913618], dtype=float32), -7.3058488813222375, False, True, {})
# self._env.step(action) =  (array([-0.93997574,  0.3412412 ,  0.9302503 ], dtype=float32), -7.5724771710866285, False, True, {})
# self._env.step(action) =  (array([-0.97957957,  0.20105676,  1.6040215 ], dtype=float32), -8.346059870502566, False, True, {})
# self._env.step(action) =  (array([-0.99978226,  0.02086785,  1.7936635 ], dtype=float32), -9.52562546106378, False, True, {})
# self._env.step(action) =  (array([-0.9879854 , -0.15454744,  1.8382236 ], dtype=float32), -9.761073958810792, False, True, {})
# self._env.step(action) =  (array([-0.9471553 , -0.32077545,  1.502177  ], dtype=float32), -8.72619067284073, False, True, {})
# self._env.step(action) =  (array([-0.91703755, -0.39880082,  0.64824027], dtype=float32), -7.744069892686247, False, True, {})
# self._env.step(action) =  (array([-0.9133964 , -0.40707123, -0.06833133], dtype=float32), -7.3987920431274485, False, True, {})
# self._env.step(action) =  (array([-0.929704  , -0.3683075 , -0.45776308], dtype=float32), -7.532718931532047, False, True, {})
# self._env.step(action) =  (array([-0.94935256, -0.3142128 , -0.63495564], dtype=float32), -7.812830025485079, False, True, {})
# self._env.step(action) =  (array([-0.9743015 , -0.22524774, -1.1174269 ], dtype=float32), -8.226009876242776, False, True, {})
# self._env.step(action) =  (array([-0.9967049 , -0.08111348, -1.4567541 ], dtype=float32), -9.140201462916012, False, True, {})
# self._env.step(action) =  (array([-0.9985732 ,  0.05340027, -1.2964362 ], dtype=float32), -9.993569235877164, False, True, {})
# self._env.step(action) =  (array([-0.98742986,  0.15805767, -0.95780826], dtype=float32), -9.317840764697069, False, True, {})
# self._env.step(action) =  (array([-0.97675335,  0.21436623, -0.4145088 ], dtype=float32), -8.735414826500692, False, True, {})
# self._env.step(action) =  (array([-0.978855  ,  0.20455521,  0.28259006], dtype=float32), -8.537354524498586, False, True, {})
# self._env.step(action) =  (array([-0.99154514,  0.12976229,  0.8808608 ], dtype=float32), -8.846706605579447, False, True, {})
# self._env.step(action) =  (array([-0.99967146,  0.02563201,  0.9975553 ], dtype=float32), -9.521184433429035, False, True, {})
# self._env.step(action) =  (array([-0.9984458 , -0.05573121,  0.7624775 ], dtype=float32), -9.834356814095322, False, True, {})
# self._env.step(action) =  (array([-0.99314696, -0.11687219,  0.59663355], dtype=float32), -9.368507656490774, False, True, {})
# self._env.step(action) =  (array([-0.9870333 , -0.16051559,  0.34141332], dtype=float32), -9.014240965923383, False, True, {})
# self._env.step(action) =  (array([-0.98773205, -0.15615806, -0.21838823], dtype=float32), -8.847832917358048, False, True, {})
# self._env.step(action) =  (array([-0.99593914, -0.09002918, -0.7741522 ], dtype=float32), -9.108421694454208, False, True, {})
# self._env.step(action) =  (array([-0.9999711 ,  0.00760107, -0.99441695], dtype=float32), -9.69901395000144, False, True, {})
# self._env.step(action) =  (array([-0.99328  ,  0.1157364, -1.176982 ], dtype=float32), -9.614324746502236, False, True, {})
# self._env.step(action) =  (array([-0.9709619 ,  0.23923407, -1.1925347 ], dtype=float32), -8.933483629772212, False, True, {})
# self._env.step(action) =  (array([-0.9452235 ,  0.32642382, -0.79653716], dtype=float32), -8.220750705421958, False, True, {})
# self._env.step(action) =  (array([-0.93306565,  0.35970613, -0.16632922], dtype=float32), -7.769255817954133, False, True, {})
# self._env.step(action) =  (array([-0.94745845,  0.3198789 ,  0.6314783 ], dtype=float32), -7.758674416662576, False, True, {})
# self._env.step(action) =  (array([-0.9747522 ,  0.22328953,  0.98317844], dtype=float32), -8.328851051551787, False, True, {})
# self._env.step(action) =  (array([-0.9935772 ,  0.11315633,  1.3302357 ], dtype=float32), -8.857308613310583, False, True, {})
# self._env.step(action) =  (array([-0.9985644 , -0.05356366,  1.6341769 ], dtype=float32), -9.985000181582945, False, True, {})
# self._env.step(action) =  (array([-0.97922397, -0.20278178,  1.5106713 ], dtype=float32), -9.30368120278126, False, True, {})
# self._env.step(action) =  (array([-0.9421697 , -0.33513618,  1.2870492 ], dtype=float32), -8.417977156958617, False, True, {})
# self._env.step(action) =  (array([-0.9052311 , -0.42491952,  0.8783163 ], dtype=float32), -7.657716860414785, False, True, {})
# self._env.step(action) =  (array([-0.879499  , -0.4759007 ,  0.47992644], dtype=float32), -7.171760974770953, False, True, {})
# self._env.step(action) =  (array([-0.8764439 , -0.4815039 , -0.15391253], dtype=float32), -6.933075953856909, False, True, {})
# self._env.step(action) =  (array([-0.9049561, -0.4255049, -0.6726727], dtype=float32), -7.15756674375225, False, True, {})
# self._env.step(action) =  (array([-0.9354843 , -0.3533683 , -0.82863605], dtype=float32), -7.558436724617683, False, True, {})
# self._env.step(action) =  (array([-0.96240836, -0.27160653, -0.83208114], dtype=float32), -8.06320968307587, False, True, {})
# self._env.step(action) =  (array([-0.98435307, -0.17620729, -1.2143447 ], dtype=float32), -8.490941725423868, False, True, {})
# self._env.step(action) =  (array([-0.9997972 , -0.02013671, -1.4999974 ], dtype=float32), -9.551789269429971, False, True, {})
# self._env.step(action) =  (array([-0.99358135,  0.11312004, -1.3660474 ], dtype=float32), -9.758954157573667, False, True, {})
# self._env.step(action) =  (array([-0.969083 ,  0.2467349, -1.3418663], dtype=float32), -8.947991933405003, False, True, {})
# self._env.step(action) =  (array([-0.9317386,  0.3631297, -1.1887852], dtype=float32), -8.164841300547922, False, True, {})
# self._env.step(action) =  (array([-0.8961753 ,  0.44370013, -0.68391186], dtype=float32), -7.493547913923468, False, True, {})
# self._env.step(action) =  (array([-0.8925706 ,  0.45090762,  0.10541693], dtype=float32), -7.128252943537696, False, True, {})
# self._env.step(action) =  (array([-0.9202355 ,  0.39136508,  0.8394475 ], dtype=float32), -7.299078748835488, False, True, {})
# self._env.step(action) =  (array([-0.9636771 ,  0.26707003,  1.4589707 ], dtype=float32), -7.9688497800050735, False, True, {})
# self._env.step(action) =  (array([-0.9954665 ,  0.09511324,  1.8123786 ], dtype=float32), -9.021713014476424, False, True, {})
# self._env.step(action) =  (array([-0.99549186, -0.09484704,  1.9369578 ], dtype=float32), -10.20707244011792, False, True, {})
# self._env.step(action) =  (array([-0.9573551 , -0.28891385,  2.0286424 ], dtype=float32), -9.078427323753003, False, True, {})
# self._env.step(action) =  (array([-0.8796794 , -0.47556725,  2.0002706 ], dtype=float32), -7.963320963553643, False, True, {})
# self._env.step(action) =  (array([-0.7961207, -0.6051378,  1.2037834], dtype=float32), -6.86945251191644, False, True, {})
# self._env.step(action) =  (array([-0.7786365 , -0.62747526,  0.07934168], dtype=float32), -6.111311970331412, False, True, {})
# self._env.step(action) =  (array([-0.8204248 , -0.57175446, -1.0616301 ], dtype=float32), -6.163965263493474, False, True, {})
# self._env.step(action) =  (array([-0.91682494, -0.3992894 , -2.198448  ], dtype=float32), -7.179069054470035, False, True, {})
# self._env.step(action) =  (array([-0.98871934, -0.14978008, -2.6442192 ], dtype=float32), -8.832075121632144, False, True, {})
# self._env.step(action) =  (array([-0.99369365,  0.11212902, -2.6262555 ], dtype=float32), -10.44154569419685, False, True, {})
# self._env.step(action) =  (array([-0.9388929,  0.3442094, -2.2543888], dtype=float32), -9.065502790893028, False, True, {})
# self._env.step(action) =  (array([-0.86300313,  0.50519854, -1.6626116 ], dtype=float32), -7.625588873131858, False, True, {})
# self._env.step(action) =  (array([-0.79571646,  0.60566926, -1.0514203 ], dtype=float32), -6.657446017136474, False, True, {})
# self._env.step(action) =  (array([-0.76302886,  0.6463644 , -0.34168664], dtype=float32), -6.081196199825939, False, True, {})
# self._env.step(action) =  (array([-0.78861827,  0.61488307,  0.7825931 ], dtype=float32), -5.9580178610675585, False, True, {})
# self._env.step(action) =  (array([-0.8871448,  0.4614912,  2.1376991], dtype=float32), -6.759214535761603, False, True, {})
# self._env.step(action) =  (array([-0.98087853,  0.19462095,  2.983243  ], dtype=float32), -8.545946359297949, False, True, {})
# self._env.step(action) =  (array([-0.99304694, -0.1177193 ,  3.111342  ], dtype=float32), -10.637549990567354, False, True, {})
# self._env.step(action) =  (array([-0.91578686, -0.40166456,  2.9665325 ], dtype=float32), -9.141475584479561, False, True, {})
# self._env.step(action) =  (array([-0.7724542 , -0.63507044,  2.60735   ], dtype=float32), -7.510972843513687, False, True, {})
# self._env.step(action) =  (array([-0.62378   , -0.78159994,  1.9351627 ], dtype=float32), -5.98820305037723, False, True, {})
# self._env.step(action) =  (array([-0.53121674, -0.8472359 ,  0.69566077], dtype=float32), -4.940918491526674, False, True, {})
# self._env.step(action) =  (array([-0.57908815, -0.81526494, -0.95354426], dtype=float32), -4.587322896316295, False, True, {})
# self._env.step(action) =  (array([-0.7178197, -0.6962291, -1.9719622], dtype=float32), -5.454967642362494, False, True, {})
# self._env.step(action) =  (array([-0.8627135 , -0.50569296, -2.5946045 ], dtype=float32), -6.644835781032613, False, True, {})
# self._env.step(action) =  (array([-0.97547925, -0.22009152, -3.2611525 ], dtype=float32), -8.44278499716969, False, True, {})
# self._env.step(action) =  (array([-0.98952264,  0.14437775, -3.8345015 ], dtype=float32), -10.807378424379719, False, True, {})
# self._env.step(action) =  (array([-0.85828775,  0.5131687 , -3.8555143 ], dtype=float32), -9.434586111444135, False, True, {})
# self._env.step(action) =  (array([-0.6350839,  0.7724431, -3.3198133], dtype=float32), -7.147816507882474, False, True, {})
# self._env.step(action) =  (array([-0.40478212,  0.91441315, -2.4308884 ], dtype=float32), -5.346483299382176, False, True, {})
# self._env.step(action) =  (array([-0.2613712,  0.9652384, -1.222696 ], dtype=float32), -3.929200375847536, False, True, {})
# self._env.step(action) =  (array([-0.22897995,  0.97343117, -0.05945876], dtype=float32), -3.2958061919465873, False, True, {})
# self._env.step(action) =  (array([-0.3079271 ,  0.95140994,  1.1492826 ], dtype=float32), -3.3597853642752504, False, True, {})
# self._env.step(action) =  (array([-0.51050425,  0.85987526,  2.6590667 ], dtype=float32), -4.219074925738517, False, True, {})
# self._env.step(action) =  (array([-0.7949644,  0.6066561,  4.1865706], dtype=float32), -6.410121762991401, False, True, {})
# self._env.step(action) =  (array([-0.9872026 ,  0.15947104,  5.0516615 ], dtype=float32), -9.73362749799558, False, True, {})
# self._env.step(action) =  (array([-0.94162005, -0.33667737,  4.9309206 ], dtype=float32), -11.913199293049463, False, True, {})
# self._env.step(action) =  (array([-0.7090456 , -0.70516264,  4.243376  ], dtype=float32), -8.674039534769971, False, True, {})
# self._env.step(action) =  (array([-0.4125495 , -0.91093516,  3.4369    ], dtype=float32), -6.162205980541891, False, True, {})
# self._env.step(action) =  (array([-0.15949236, -0.9871992 ,  2.3116205 ], dtype=float32), -4.303778396193658, False, True, {})
# self._env.step(action) =  (array([-0.03523165, -0.99937916,  0.8841157 ], dtype=float32), -2.9840127143973394, False, True, {})
# self._env.step(action) =  (array([-0.04783285, -0.99885535, -0.4039412 ], dtype=float32), -2.559018808599723, False, True, {})
# self._env.step(action) =  (array([-0.18438463, -0.9828542 , -1.7928835 ], dtype=float32), -2.8698570405378265, False, True, {})
# self._env.step(action) =  (array([-0.4593047, -0.8882788, -3.217993 ], dtype=float32), -4.246784847697971, False, True, {})
# self._env.step(action) =  (array([-0.7784232 , -0.62773985, -4.526689  ], dtype=float32), -6.426487654075957, False, True, {})
# self._env.step(action) =  (array([-0.99116737, -0.13261674, -5.7504473 ], dtype=float32), -10.072652354704875, False, True, {})
# self._env.step(action) =  (array([-0.88855433,  0.45877138, -6.0605464 ], dtype=float32), -12.569199089846805, False, True, {})
# self._env.step(action) =  (array([-0.51457906,  0.8574429 , -5.2986693 ], dtype=float32), -8.981329645230327, False, True, {})
# self._env.step(action) =  (array([-0.09156828,  0.9957988 , -4.277237  ], dtype=float32), -5.732743834298823, False, True, {})
# self._env.step(action) =  (array([ 0.24119325,  0.9704771 , -2.8821166 ], dtype=float32), -3.6285247500733635, False, True, {})
# self._env.step(action) =  (array([ 0.4052332 ,  0.91421336, -1.51383   ], dtype=float32), -1.8978521268390676, False, True, {})
# self._env.step(action) =  (array([ 0.4680356 ,  0.8837096 , -0.30691788], dtype=float32), -1.3273045452857697, False, True, {})
# self._env.step(action) =  (array([0.39814755, 0.9173214 , 1.0808094 ], dtype=float32), -1.2483321620786159, False, True, {})
# self._env.step(action) =  (array([0.18927269, 0.9819246 , 2.673342  ], dtype=float32), -1.8489344450124792, False, True, {})
# self._env.step(action) =  (array([-0.19882153,  0.9800357 ,  4.147524  ], dtype=float32), -3.790420594252564, False, True, {})
# self._env.step(action) =  (array([-0.6333278,  0.7738837,  5.0977244], dtype=float32), -6.139624341089813, False, True, {})
# self._env.step(action) =  (array([-0.94632316,  0.32322198,  5.6380134 ], dtype=float32), -9.408222907325051, False, True, {})
# self._env.step(action) =  (array([-0.9756741 , -0.21922615,  5.3932657 ], dtype=float32), -12.71617901651734, False, True, {})
# self._env.step(action) =  (array([-0.75918084, -0.65087974,  4.778588  ], dtype=float32), -9.615203480015039, False, True, {})
# self._env.step(action) =  (array([-0.43460992, -0.9006188 ,  3.8162563 ], dtype=float32), -6.854375050927895, False, True, {})
# self._env.step(action) =  (array([-0.17174388, -0.98514163,  2.414393  ], dtype=float32), -4.4519397727682115, False, True, {})
# self._env.step(action) =  (array([-0.05667955, -0.9983924 ,  0.6356136 ], dtype=float32), -3.040192531062256, False, True, {})
# self._env.step(action) =  (array([-0.13414475, -0.99096173, -1.1441276 ], dtype=float32), -2.733408835003562, False, True, {})
# self._env.step(action) =  (array([-0.3534664, -0.9354472, -2.6634371], dtype=float32), -3.5862843375704956, False, True, {})
# self._env.step(action) =  (array([-0.66305774, -0.74856824, -3.8455923 ], dtype=float32), -5.600972791706398, False, True, {})
# self._env.step(action) =  (array([-0.9225191 , -0.38595143, -4.8135734 ], dtype=float32), -8.021914171721587, False, True, {})
# self._env.step(action) =  (array([-0.99165094,  0.12895118, -5.2200847 ], dtype=float32), -11.86015292205699, False, True, {})
# self._env.step(action) =  (array([-0.81696165,  0.57669204, -4.753198  ], dtype=float32), -10.097410621497856, False, True, {})
# self._env.step(action) =  (array([-0.50737447,  0.8617257 , -4.083813  ], dtype=float32), -7.257873784770891, False, True, {})
# self._env.step(action) =
